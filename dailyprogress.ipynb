# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/daily_progress_chart.csv")

# %%
df.head()
print (df)
# Out:
#        Date  Total_time  namaz_unit_OD  Unit_time_namaz_OD  \
# 0    1-8-26        1440              6                  15
# 1    2-8-26        1440              6                  15
# 2    3-8-26        1440              6                  15
# 3    4-8-26        1440              6                  15
# 4    5-8-26        1440              6                  15
# 5    6-8-26        1440              6                  15
# 6    7-8-26        1440              6                  15
# 7    8-8-26        1440              6                  15
# 8    9-8-26        1440              6                  15
# 9   10-8-26        1440              6                  15
# 10  11-8-26        1440              6                  15
# 11  12-8-26        1440              6                  15
# 12  13-8-26        1440              6                  15
# 13  14-8-26        1440              6                  15
# 14  15-8-26        1440              6                  15
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Total_time', 'namaz_unit_OD', 'Unit_time_namaz_OD',
#        'Total_time_namaz_OD', 'W_namaz_OD', 'namaz_unit_ED',
#        'Unit_time_namaz_ED', 'Total_time_namaz_ED', 'W_namaz_ED',
#        'quran_unit_OD', 'Unit_time_quran_OD', 'Total_time_quran_OD',
#        'W_quran_OD', 'quran_unit_ED', 'Unit_time_quran_ED',
#        'Total_time_quran_ED', 'W_quran_ED', 'eating_unit_OD',
#        'Unit_time_eating_OD', 'Total_time_eating_OD', 'W_eating_OD',
#        'eating_unit_ED', 'Unit_time_eating_ED', 'Total_time_eating_ED',
#        'W_eating_ED', 'Sleeping_unit_OD', 'Unit_time_sleeping_OD',
#        'Total_time_sleeping_OD', 'W_sleeping_OD', 'sleep_unit_ED',
#        'Unit_time_sleep_ED', 'Total_time_sleep_ED', 'W_sleep_ED',
#        'exercise_unit_OD', 'Unit_time_exercise_OD', 'Total_time_exercise_OD',
#        'W_exercise_OD', 'exercise_unit_ED', 'Unit_time_exercise_ED',
#        'Total_time_exercise_ED', 'W_exercise_ED', 'office_work_unit_OD',
# ...

# %%
df = df.round(2)

# %% [markdown]
# # Data Input

# %%
df.at[4, "namaz_unit_ED"] = 1
df.at[3, "quran_unit_ED"] = 1
df.at[3, "eating_unit_ED"] = 1
df.at[3, "sleep_unit_ED"] = 7
df.at[3, "exercise_unit_ED"] = 1
df.at[3, "office_work_unit_ED"] = 4
df.at[3, "coding_unit_ED"] = 2
df.at[3, "study_book_unit_ED"] = 1
df.at[3, "Writing_Speaking_unit_ED"] = 1
df.at[3, "Family_unit_time_ED"] = 2

# %%
# manipulation and preprocessing dataframe
df["Total_time_namaz_ED"] = df ["namaz_unit_ED"] * df ["Unit_time_namaz_ED"]
df["W_namaz_ED"] =  df ["Total_time_namaz_ED"] / df ["Total_time"] * 10 
df["W_namaz_ED"] = df["W_namaz_ED"].round(2)

df["Total_time_eating_OD"] = df ["quran_unit_ED"] * df ["Unit_time_quran_ED"]
df["W_quran_ED"] =  df ["Total_time_eating_OD"] / df ["Total_time"] * 10 
df["W_quran_ED"] = df["W_quran_ED"].round(2)

df["Total_time_eating_ED"] = df ["eating_unit_ED"] * df ["Unit_time_eating_ED"]
df["W_eating_ED"] =  df ["Total_time_eating_ED"] / df ["Total_time"] * 10 
df["W_eating_ED"] = df["W_eating_ED"].round(2)

df["Total_time_sleep_ED"] = df ["sleep_unit_ED"] * df ["Unit_time_sleep_ED"]
df["W_sleep_ED"] =  df ["Total_time_sleep_ED"] / df ["Total_time"] * 10 
df["W_sleep_ED"] = df["W_sleep_ED"].round(2)

df["Total_time_exercise_ED"] = df ["exercise_unit_ED"] * df ["Unit_time_exercise_ED"]
df["W_exercise_ED"] =  df ["Total_time_eating_ED"] / df ["Total_time"] * 10 
df["W_exercise_ED"] = df["W_exercise_ED"].round(2)

df["Total_time_office_work_ED"] = df ["office_work_unit_ED"] * df ["Unit_time_office_work_ED"]
df["W_office_work_ED"] =  df ["Total_time_office_work_ED"] / df ["Total_time"] * 10 
df["W_office_work_ED"] = df["W_office_work_ED"].round(2)

df["Total_time_coding_ED"] = df ["coding_unit_ED"] * df ["Unit_time_coding_ED"]
df["W_coding_ED"] =  df ["Total_time_coding_ED"] / df ["Total_time"] * 10 
df["W_coding_ED"] = df["W_coding_ED"].round(2)

df["Total_time_sb_ED"] = df ["study_book_unit_ED"] * df ["Unit_time_sb_ED"]
df["W_sb_ED"] =  df ["Total_time_sb_ED"] / df ["Total_time"] * 10
df["W_sb_ED"] = df["W_sb_ED"].round(2)

df["Total_time_WS_ED"] = df ["Writing_Speaking_unit_ED"] * df ["Unit_time_WS_ED"]
df["W_writing_speakig_ED"] =  df ["Total_time_WS_ED"] / df ["Total_time"] * 10
df["W_writing_speakig_ED"] = df["W_writing_speakig_ED"].round(2)

df["family_total_time_ED"] = df ["Family_unit_time_ED"] * df ["family__time_ED"]
df["W_family_time_ED"] =  df ["family_total_time_ED"] / df ["Total_time"] * 10
df["W_family_time_ED"] = df["W_family_time_ED"].round(2)

df["Sum_of_OD"] = df ["W_namaz_OD"] + df ["W_quran_OD"]+ df ["W_eating_OD"] + df ["W_sleeping_OD"] + df ["W_exercise_OD"] + df ["W_coffice_work_OD"] + df ["W_coding_OD"] + df ["W_study_book_OD"] + df ["W_writing_speakig_OD"] + df ["W_family_time_OD"]
df["Sum_of_OD"] = df["Sum_of_OD"].round(2)


df["Sum_of_ED"] = df ["W_namaz_ED"] + df ["W_quran_ED"]+ df ["W_eating_ED"] + df ["W_sleep_ED"] + df ["W_exercise_ED"] + df ["W_office_work_ED"] + df ["W_coding_ED"] + df ["W_sb_ED"] + df ["W_writing_speakig_ED"] + df ["W_family_time_ED"]
df["Sum_of_ED"] = df["Sum_of_ED"].round(2)

# %%
df.head()
print (df)
# Out:
#        Date  Total_time  namaz_unit_OD  Unit_time_namaz_OD  \
# 0    1-8-26        1440              6                  15
# 1    2-8-26        1440              6                  15
# 2    3-8-26        1440              6                  15
# 3    4-8-26        1440              6                  15
# 4    5-8-26        1440              6                  15
# 5    6-8-26        1440              6                  15
# 6    7-8-26        1440              6                  15
# 7    8-8-26        1440              6                  15
# 8    9-8-26        1440              6                  15
# 9   10-8-26        1440              6                  15
# 10  11-8-26        1440              6                  15
# 11  12-8-26        1440              6                  15
# 12  13-8-26        1440              6                  15
# 13  14-8-26        1440              6                  15
# 14  15-8-26        1440              6                  15
# ...

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_namaz_OD", "W_namaz_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_quran_OD", "W_quran_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    "Data" : df["Date"],
    "Origial_data": df["W_quran_OD"],
    "Experimental_data":  df["W_quran_ED"],
}
fig, ax = plt.subplots(layout='constrained')

res = ax.grouped_bar(penguin_means, tick_labels=species, group_spacing=1)
for container in res.bar_containers:
    ax.bar_label(container, padding=3)

# Add some text for labels, title, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 9
#       2 penguin_means = {
#       3     "Data" : df["Date"],
#       4     "Origial_data": df["W_quran_OD"],
#       5     "Experimental_data":  df["W_quran_ED"],
#       6 }
#       7 fig, ax = plt.subplots(layout='constrained')
# ----> 9 res = ax.grouped_bar(penguin_means, tick_labels=species, group_spacing=1)
#      10 for container in res.bar_containers:
#      11     ax.bar_label(container, padding=3)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:3369, in Axes.grouped_bar(self, heights, positions, group_spacing, bar_spacing, tick_labels, labels, orientation, colors, **kwargs)
#    3367 if tick_labels is not None:
#    3368     if orientation == "vertical":
# -> 3369         self.xaxis.set_ticks(group_centers, labels=tick_labels)
#    3370     else:
# ...

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_eating_OD", "W_eating_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_sleeping_OD", "W_sleep_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_exercise_OD", "W_exercise_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_coffice_work_OD", "W_office_work_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_coding_OD", "W_coding_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_study_book_OD", "W_sb_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_writing_speakig_OD", "W_writing_speakig_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "W_family_time_OD", "W_family_time_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#df.plot (x = "Sum_of_ED", y = "Total_time", kind = "bar")
# Method 1: Quick plot directly from the dataframe
df.plot(x="Date", y= [ "Sum_of_OD", "Sum_of_ED",], kind='line')

# Add final Matplotlib adjustments
plt.title("Daily_Progress")
plt.ylabel("Date")
plt.ylabel("Weighted_achieve")
plt.show()

# %%
#Save to a new CSV (or overwrite)
df.to_csv('data/daily_progress_chart.csv', index=False)
